# %% [markdown]
# ## 1. Read and load the Dataset

# %%
import pandas as pd 
df = pd.read_csv('matches.csv')
df.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %% [markdown]
# # 2. Who won the toss most number of times ?

# %%
df['toss_winner'].value_counts().reset_index(0)
# Out:
#                           index  toss_winner
# 0                Mumbai Indians           98
# 1         Kolkata Knight Riders           92
# 2           Chennai Super Kings           89
# 3   Royal Challengers Bangalore           81
# 4               Kings XI Punjab           81
# 5              Delhi Daredevils           80
# 6              Rajasthan Royals           80
# 7           Sunrisers Hyderabad           46
# 8               Deccan Chargers           43
# 9                 Pune Warriors           20
# 10                Gujarat Lions           15
# 11               Delhi Capitals           10
# 12         Kochi Tuskers Kerala            8
# 13      Rising Pune Supergiants            7
# 14       Rising Pune Supergiant            6

# %% [markdown]
# ### Mumbai Indians won the toss most number of times.

# %% [markdown]
# # 3.Who won the "Player of the match" award maximum number of times ?

# %%
df['player_of_match'].value_counts().reset_index()
# Out:
#               index  player_of_match
# 0          CH Gayle               21
# 1    AB de Villiers               20
# 2         RG Sharma               17
# 3          MS Dhoni               17
# 4         DA Warner               17
# ..              ...              ...
# 221  PD Collingwood                1
# 222         NV Ojha                1
# 223        AC Voges                1
# 224        J Theron                1
# 225       S Hetmyer                1
#
# [226 rows x 2 columns]

# %% [markdown]
# ### Christpher Henry Gayle won the player of the match award most number of times

# %% [markdown]
# ## 4. Number of rows and columns of this dataset?

# %%
df.shape
# Out:
# (756, 18)

# %% [markdown]
# # 5.How many times Mumbai Indians have win the match?

# %%
df.loc[df["winner"]=="Mumbai Indians"].count().reset_index()
# Out:
#               index    0
# 0                id  109
# 1            season  109
# 2              city  109
# 3              date  109
# 4             team1  109
# 5             team2  109
# 6       toss_winner  109
# 7     toss_decision  109
# 8            result  109
# 9        dl_applied  109
# 10           winner  109
# 11      win_by_runs  109
# 12   win_by_wickets  109
# 13  player_of_match  109
# 14            venue  109
# 15          umpire1  109
# 16          umpire2  109
# 17          umpire3   17

# %% [markdown]
# # 6. Which team has won most times with the margin of over 100 runs?

# %%
df = df[((df['win_by_runs']>100))]
df['winner'].value_counts()
# Out:
# Royal Challengers Bangalore    3
# Mumbai Indians                 2
# Kolkata Knight Riders          1
# Rajasthan Royals               1
# Kings XI Punjab                1
# Sunrisers Hyderabad            1
# Name: winner, dtype: int64

# %% [markdown]
# # 7. Which team has won most times with the margin of 10 wickets?

# %%
df1 = df[((df['win_by_wickets']==10))]
df['winner'].value_counts().reset_index()
# Out:
#                          index  winner
# 0  Royal Challengers Bangalore       3
# 1        Kolkata Knight Riders       1
# 2              Kings XI Punjab       1
# 3              Deccan Chargers       1
# 4             Delhi Daredevils       1
# 5             Rajasthan Royals       1
# 6               Mumbai Indians       1
# 7          Chennai Super Kings       1
# 8          Sunrisers Hyderabad       1
